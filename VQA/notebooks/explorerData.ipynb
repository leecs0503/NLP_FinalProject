# %% [markdown]
# Annotation의 구조를 보기 위해 만든 노트북

# %%
import pandas as pd
import os
import json
train_annotation_data = json.load(open(os.path.join('..', 'datasets', 'Annotations', 'v2_mscoco_train2014_annotations.json')))
train_annotation = pd.DataFrame(train_annotation_data["annotations"])

train_annotation.head(20)
# Out:
#          question_type multiple_choice_answer  \
# 0         what is this                    net
# 1                 what                pitcher
# 2    what color is the                 orange
# 3              is this                    yes
# 4    what color is the                  white
# 5   what is the person                 skiing
# 6    what color is the                    red
# 7       what is in the                frisbee
# 8               is the                    yes
# 9               is the                frisbee
# 10              is the                    yes
# 11            is there                    yes
# 12         what is the               contrail
# 13              is the                    yes
# 14   what color is the       white and purple
# 15         what is the         brushing teeth
# 16                  is                    yes
# 17          is the man                     no
# 18         what is the               frowning
# 19   none of the above                     no
#
#                                               answers  image_id answer_type  \
# 0   [{'answer': 'net', 'answer_confidence': 'maybe...    458752       other
# 1   [{'answer': 'pitcher', 'answer_confidence': 'y...    458752       other
# 2   [{'answer': 'orange', 'answer_confidence': 'ye...    458752       other
# 3   [{'answer': 'yes', 'answer_confidence': 'yes',...    458752      yes/no
# 4   [{'answer': 'white', 'answer_confidence': 'yes...    262146       other
# 5   [{'answer': 'skiing', 'answer_confidence': 'ye...    262146       other
# 6   [{'answer': 'red', 'answer_confidence': 'yes',...    262146       other
# 7   [{'answer': 'frisbee', 'answer_confidence': 'y...    524291       other
# 8   [{'answer': 'yes', 'answer_confidence': 'yes',...    524291      yes/no
# 9   [{'answer': 'frisbee', 'answer_confidence': 'y...    524291       other
# 10  [{'answer': 'yes', 'answer_confidence': 'yes',...    393221      yes/no
# 11  [{'answer': 'yes', 'answer_confidence': 'yes',...    393221      yes/no
# 12  [{'answer': 'airplane', 'answer_confidence': '...    393221       other
# 13  [{'answer': 'yes', 'answer_confidence': 'yes',...    393223      yes/no
# 14  [{'answer': 'white and purple', 'answer_confid...    393223       other
# 15  [{'answer': 'brushing teeth', 'answer_confiden...    393223       other
# 16  [{'answer': 'yes', 'answer_confidence': 'yes',...    393223      yes/no
# 17  [{'answer': 'no', 'answer_confidence': 'yes', ...    393224      yes/no
# 18  [{'answer': 'waiting', 'answer_confidence': 'm...    393224       other
# 19  [{'answer': 'yes', 'answer_confidence': 'yes',...    393224      yes/no
#
#     question_id
# 0     458752000
# 1     458752001
# 2     458752002
# 3     458752003
# 4     262146000
# 5     262146001
# 6     262146002
# 7     524291000
# 8     524291001
# 9     524291002
# 10    393221000
# 11    393221001
# 12    393221002
# 13    393223000
# 14    393223001
# 15    393223002
# 16    393223003
# 17    393224000
# 18    393224001
# 19    393224002

# %%
train_question_data = json.load(open(os.path.join('..', 'datasets', 'Questions', 'v2_OpenEnded_mscoco_train2014_questions.json')))
train_question = pd.DataFrame(train_question_data["questions"])

train_annotation.head(20)

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

idx = 50
idx_answers = pd.DataFrame(train_annotation.loc[idx, 'answers'])
quest = train_annotation.loc[idx, 'question_id']
question = train_question[train_question['question_id']==quest]['question'][idx]
image_id = train_question[train_question['question_id']==quest]['image_id'][idx]
image_path = os.path.join('..','datasets','Images','train2014',f'COCO_train2014_{image_id:012}.jpg')
img = mpimg.imread(image_path)
imgplot = plt.imshow(img)
plt.show()

print(question)
idx_answers
# Out:
# What is she holding?
#       answer answer_confidence  answer_id
# 0      poles               yes          1
# 1  ski poles               yes          2
# 2      poles               yes          3
# 3       skis               yes          4
# 4  ski poles               yes          5
# 5   ski pole               yes          6
# 6       pole             maybe          7
# 7      poles             maybe          8
# 8      poles               yes          9
# 9      poles               yes         10
